# %% [markdown]
# # CSS Labs: Template
# This notebook is a style guide and example template for CSS Labs. The text here is an abstract describing the entire notebook.
#
# ## Contents
# 1. [Background](#Section-1%3A-Background)
# 1. [Setup](#Section-2%3A-Setup)
#     * [2.1 Import python modules](#2.1-Import-Python-Modules)
#     * [2.2 Load data](#2.2-Load-Data)
# 1. [CSS Concept](#Section-3%3A-CSS-Concept)
#     * [3.2 CSS Exercise](#3.1-CSS-Exercise)
# 1. [Reflection](#Section-4%3A-Reflection)
# 2. [References](#References)

# %% [markdown]
# ## Section 1: Background
# ### 1.1 Learning Objectives
# 1. Learn how to format a CSS Lab.
# 2. Create a template for easily making new labs
#
# ### 1.2 Data
# Most of these labs will need data. This is just an example so it doesn't really need data, but we can get some from NetworkX just because.

# %% [markdown]
# ## Section 2: Setup
# ### 2.1 Import Python Modules
# Run the following cell to import the necessary python modules.

# %%
# Initialization
# %pylab inline
import matplotlib.pyplot as plt
import networkx as nx
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### 2.2 Load Data
# Run the following cell to import the data.

# %%
G = nx.karate_club_graph()

# %% [markdown]
# ## Section 3: CSS Concept
# Computational social science is pretty cool, especially if you like computers and people and science.

# %% [markdown]
# ### 3.1 CSS Exercise
# Students will be asked to try out excersizes to demonstrate CSS tools, methods, and concepts.

# %%
nx.draw(G)

# %% [markdown]
# #### Short Answer 1
# The above diagram was produced by an exercise and can be referenced in a short answer question. In a few sentences, describe the animal most closely resembling the above diagram.

# %% [markdown]
# 🤔 Your answer here:

# %% [markdown]
# ## Section 4: Reflection
#
# #### Reflection Question 1
# Here is a reflection question that includes a short code sample. Run the code sample before answering the question.

# %%
import collections
degree_sequence = sorted([d for n, d in G.degree()], reverse=True)
degree_count = collections.Counter(degree_sequence)
deg, cnt = zip(*degree_count.items())
fig, ax = plt.subplots()
plt.bar(deg, cnt, width=0.80, color='b')
# Out:
# <Container object of 11 artists>

# %% [markdown]
# 🤔 Your answer here:

# %% [markdown]
# #### Reflection Question 2
# This reflection question doesn't have any associated code. In the space below, write a few sentences answering the following question. Can spiders have fun?

# %% [markdown]
# 🤔 Your answer here:

# %% [markdown]
# ## References
#
# (SDW2006) Salganik, M. J., Dodds, P. S., & Watts, D. J. (2006). Experimental study of inequality and unpredictability in an artificial cultural market. _Science_, 311(5762), 854-856.
#
# (CSW2016) Chen, D.L., Schonger, M., & Wickens, C. (2016). oTree - An open-source platform for laboratory, online and field experiments. _Journal of Behavioral and Experimental Finance_, 9, 88-97.
